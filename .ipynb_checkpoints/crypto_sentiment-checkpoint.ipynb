# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the news api to pull the latest news articles for bitcoin and ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports

import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
from newsapi.newsapi_client import NewsApiClient

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/keirangugula/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read api key environment variable

load_dotenv()
api_key = os.getenv("apiKey")

# %%
# Create a newsapi client

newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles

bitcoin_articles = newsapi.get_everything(q="bitcoin",
                                          language='en',
                                          sort_by='relevancy',
                                        
                                         )

# %%
# Fetch the Ethereum news articles

ethereum_articles = newsapi.get_everything(q='ethereum',
                                           language='en',
                                           sort_by='relevancy'
                                          )

# %%
# Create the Bitcoin sentiment scores DataFrame

bitcoin_sentiments = []

for article in bitcoin_articles["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        bitcoin_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
bitcoin_df = pd.DataFrame(bitcoin_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
bitcoin_df = bitcoin_df[cols]

bitcoin_df.head()
# Out:
#          date                                               text  compound  \
# 0  2020-11-12  A former Microsoft software engineer from Ukra...   -0.6705
# 1  2020-12-03  Visa has partnered with cryptocurrency startup...    0.6369
# 2  2020-11-12  PayPal is bringing its newly-announced support...    0.2144
# 3  2020-11-20  In November 2017, after an absolutely massive,...    0.2023
# 4  2020-12-06  Unlike ‘conventional’ cryptocurrencies, a cent...    0.0000
#
#    positive  negative  neutral
# 0     0.064     0.199    0.737
# 1     0.162     0.000    0.838
# 2     0.053     0.000    0.947
# 3     0.050     0.000    0.950
# 4     0.000     0.000    1.000

# %%
# Create the Ethereum sentiment scores DataFrame

ethereum_sentiments = []

for article in ethereum_articles["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        ethereum_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame

ethereum_df = pd.DataFrame(ethereum_sentiments)

# Reorder DataFrame columns

cols = ["date", "text", "compound", "positive", "negative", "neutral"]
ethereum_df = ethereum_df[cols]

# %%
# Describe the Bitcoin Sentiment

bitcoin_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  19.000000  19.000000  19.000000  19.000000
# mean    0.135189   0.060526   0.025737   0.913737
# std     0.379635   0.065557   0.066192   0.098593
# min    -0.670500   0.000000   0.000000   0.716000
# 25%     0.000000   0.000000   0.000000   0.833500
# 50%     0.000000   0.050000   0.000000   0.950000
# 75%     0.411700   0.102500   0.000000   1.000000
# max     0.765000   0.174000   0.215000   1.000000

# %%
# Describe the Ethereum Sentiment

ethereum_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.122565   0.060950   0.021050   0.918000
# std     0.320198   0.078682   0.054473   0.105304
# min    -0.493900   0.000000   0.000000   0.672000
# 25%     0.000000   0.000000   0.000000   0.876000
# 50%     0.000000   0.052000   0.000000   0.948000
# 75%     0.261275   0.095250   0.000000   1.000000
# max     0.877900   0.318000   0.196000   1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Ethereum had the highest mean positive score
#
# Q: Which coin had the highest compound score?
#
# A: Bitcoin has the highest compound score
#
# Q. Which coin had the highest positive score?
#
# A: Ethereum has the highest positive score (max=0.31)

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word
# 2. Remove Punctuation
# 3. Remove Stopwords

# %%
# Import libraries

from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Initialize lemmatizer

lemmatizer = WordNetLemmatizer()

# %%
# Construct stop words list

sw_addons = ['said', 'sent', 'including', 'today', 'announced', 'week', 'basically', 'also', 'file', 'reuters', 'illustration', 'bitcoin', 'ethereum', 'char', 'ha', 'li', 'currency', 'virtual', 'photo', 'dado', 'ruvic']

# %%
# Complete the tokenizer function

def tokenizer(articles):
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub(' ', articles)
    words = word_tokenize(re_clean)
    lem = [lemmatizer.lemmatize(word) for word in words]
    output = [word.lower() for word in lem if word.lower() not in sw.union(sw_addons)]
    return output

# %%
# Create series object to pass into new function

bitcoin_series = bitcoin_df.text
ethereum_series = ethereum_df.text

# %%
# Create new function to put each tokenized article into a list (this makes concating it to the original df easier)

def organizeAndTokenize(articles):
    
    tokens = []
    column_count = 0
    
    for article in articles:
        tokens.append(tokenizer(articles.iloc[column_count]))
        column_count += 1
    return tokens

# %%
# Add bitcoin tokens column to original df

bitcoin_column = organizeAndTokenize(bitcoin_series)
bitcoin_df['tokens'] = bitcoin_column

# %%
# Create a new tokens column for Ethereum

ethereum_column = organizeAndTokenize(ethereum_series)
ethereum_df['tokens'] = ethereum_column
ethereum_df.head()
# Out:
#          date                                               text  compound  \
# 0  2020-11-12  PayPal is bringing its newly-announced support...    0.2144
# 1  2020-11-23  FILE PHOTO: Representation of the Ethereum vir...    0.0000
# 2  2020-11-23  FILE PHOTO: Representation of the Ethereum vir...    0.0000
# 3  2020-11-23  LONDON (Reuters) - Digital currencies Ethereum...    0.4215
# 4  2020-12-07  NEW YORK (Reuters) - Institutional investors p...    0.1779
#
#    positive  negative  neutral  \
# 0     0.053       0.0    0.947
# 1     0.000       0.0    1.000
# 2     0.000       0.0    1.000
# 3     0.088       0.0    0.912
# 4     0.052       0.0    0.948
#
#                                               tokens
# 0  [paypal, bringing, newly, support, cryptocurre...
# 1  [representation, standing, pc, motherboard, se...
# 2  [representation, standing, pc, motherboard, se...
# 3  [london, digital, xrp, soared, monday, gaining...
# 4  [new, york, institutional, investor, pumped, m...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
# Import libraries

from collections import Counter
from nltk import ngrams

# %%
# Convert list of list into a flattened list

bitcoin_token_list = [word for sublist in bitcoin_column for word in sublist]
ethereum_token_list = [word for sublist in ethereum_column for word in sublist]

# %%
# Generate the Bitcoin N-grams where N=2

bitcoin_bigram = Counter(ngrams(bitcoin_token_list, n=2))
print(dict(bitcoin_bigram))
# Out:
# {('former', 'microsoft'): 2, ('microsoft', 'software'): 2, ('software', 'engineer'): 2, ('engineer', 'ukraine'): 2, ('ukraine', 'sentenced'): 2, ('sentenced', 'nine'): 2, ('nine', 'year'): 2, ('year', 'prison'): 2, ('prison', 'stealing'): 2, ('stealing', 'million'): 2, ('million', 'store'): 2, ('store', 'credit'): 2, ('credit', 'microsoft'): 2, ('microsoft', 'online'): 2, ('online', 'store'): 1, ('store', 'volod'): 1, ('volod', 'visa'): 1, ('visa', 'partnered'): 1, ('partnered', 'cryptocurrency'): 1, ('cryptocurrency', 'startup'): 1, ('startup', 'blockfi'): 1, ('blockfi', 'offer'): 1, ('offer', 'first'): 1, ('first', 'reward'): 1, ('reward', 'credit'): 1, ('credit', 'card'): 1, ('card', 'pay'): 1, ('pay', 'rather'): 1, ('rather', 'cash'): 1, ('cash', 'worth'): 1, ('worth', 'applying'): 1, ('applying', 'unless'): 1, ('unless', 'youre'): 1, ('youre', 'extremely'): 1, ('extremely', 'bullish'): 1, ('bullish', 'paypal'): 1, ('paypal', 'bringing'): 1, ('bringing', 'newly'): 1, ('newly', 's
# ...

# %%
# Generate the Ethereum N-grams where N=2

ethereum_bigram = Counter(ngrams(ethereum_token_list, n=2))

# %%
# Use the token_count function to generate the top 10 words from each coin
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Get the top 10 words for Bitcoin

bitcoin_top10 = token_count(bitcoin_token_list,N=10)
bitcoin_top10
# Out:
# [('cryptocurrency', 5),
#  ('microsoft', 4),
#  ('year', 4),
#  ('november', 4),
#  ('digital', 4),
#  ('taken', 4),
#  ('million', 3),
#  ('store', 3),
#  ('credit', 3),
#  ('first', 3)]

# %%
# Get the top 10 words for Ethereum

ethereum_top10 = token_count(ethereum_token_list, N=10)
ethereum_top10
# Out:
# [('representation', 8),
#  ('seen', 7),
#  ('taken', 7),
#  ('new', 6),
#  ('staff', 6),
#  ('cryptocurrency', 5),
#  ('london', 5),
#  ('york', 5),
#  ('november', 5),
#  ('paypal', 4)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
# Import libraries

from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud

bitcoin_bigStr = ','.join(bitcoin_token_list)
wc = WordCloud().generate(bitcoin_bigStr)
plt.imshow(wc)

# %%
# Generate the Ethereum word cloud

ethereum_bigStr = ','.join(ethereum_token_list)
wc = WordCloud().generate(ethereum_bigStr)
plt.imshow(wc)

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
# Import libraries

import spacy
import en_core_web_sm
from spacy import displacy

# %%
# Download a language model for SpaCy
# !python -m spacy download en_core_web_sm
# Out:
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
# Load the spaCy model

nlp = en_core_web_sm.load()

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Run the NER processor on all of the text

bitcoin_doc = nlp(bitcoin_bigStr)

# Add a title to the document

bitcoin_doc.user_data["title"] = "Bitcoin Text --> Named Entity Recognition"

# %%
# Render the visualization

displacy.render(bitcoin_doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin Text --> Named Entity Recognition</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">former,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     microsoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,software,engineer,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ukraine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,sentenced,
# ...

# %%
# List all Entities

print([ent for ent in bitcoin_doc.ents])
# Out:
# [microsoft, ukraine, nine,year, million, microsoft, visa, blockfi, first, first, us, october, november, two,month, first, time, next,day, digital,yuan, china, digital, hype, mal, six,year, launch, mexico, crypto, u, november, november, monthly, april, fourth, williams, arya, stark, catelyn, lord, eddard, acolyte, monday, twitt, microsoft, ukraine, nine,year, million, microsoft, tuesday, evening, december, march, tom, wilson, chavez, justin, harperbusiness, bbc,news, cryptocurrency, three,year, digital, cur, november, tokyo, motherboard, february, london, london, digital, xrp, monday, london]

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Run the NER processor on all of the text

ethereum_doc = nlp(ethereum_bigStr)

# Add a title to the document

ethereum_doc.user_data['title'] = 'Ethereum Text --> Named Entity Recognition'

# %%
# Render the visualization

displacy.render(ethereum_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum Text --> Named Entity Recognition</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">paypal,bringing,newly,support,cryptocurrency,us,account,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# ,plan,open,cryptocurrency,trading,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     us
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,based,user,
# ...

# %%
# List all Entities

print([ent for ent in ethereum_doc.ents])
# Out:
# [first, us, october, motherboard, february, london, motherboard, february, london, london, digital, xrp, monday, new,york, million, manag, new,york, million, november, graph, november, new,york, un, crypto, february,year, one, last,month,, october, november, new,york, btc, btsp, rose, november, new,york, btc, btsp, rose, november, london, london, hala, hedera, syrians, tech, sunnyvale, california, october, stephen, lam, ul]

# %% [markdown]
# ---
